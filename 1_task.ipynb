# %%
# Out:
# PyPlot.Figure(PyObject <Figure size 763.636x680 with 1 Axes>)
# Robot(HorizonSideRobots.SituationDatas.SituationData((0x000000000000000b, 0x000000000000000c), 1.0, true, (11, 1), [119 -147 … -165 -169; -145 182 … 324 -87; … ; -113 251 … 275 357; -237 399 … 28 408], Set{Tuple{Int64, Int64}}(), Set{HorizonSide}[Set() Set() … Set() Set(); Set() Set() … Set() Set(); … ; Set() Set() … Set() Set(); Set() Set() … Set() Set()]), true, nothing)

# %%
# 1 Задание
using HorizonSideRobots
r=Robot(animate=true)
for i = 1:5
    move!(r, HorizonSide(3))
end

for i = 1:4
    move!(r, HorizonSide(0))
end

putmarker!(r)
for i = 1:2
    
    move!(r, HorizonSide(2))
    move!(r, HorizonSide(1))
    putmarker!(r)
end

for i = 1:4
    
    move!(r, HorizonSide(3))
    move!(r, HorizonSide(0))
    putmarker!(r)
end

for i = 1:2
    
    move!(r, HorizonSide(2))
    move!(r, HorizonSide(1))
    
end

for i = 1:5
    move!(r, HorizonSide(1))
    move!(r, HorizonSide(0))
    putmarker!(r)
end

for i = 1:9
    move!(r, HorizonSide(2))
    move!(r, HorizonSide(3))
    putmarker!(r)
end

for i = 1:4
    move!(r, HorizonSide(1))
    move!(r, HorizonSide(0))
    
end

for i = 1:4
    move!(r, HorizonSide(2))
    move!(r, HorizonSide(1))
    putmarker!(r)
end

for i = 1:10
    move!(r, HorizonSide(3))
    move!(r, HorizonSide(0))
    putmarker!(r)
end

for i = 1:6
    move!(r, HorizonSide(2))
    move!(r, HorizonSide(1))
    
end
# Out:
# sys:1: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
# PyPlot.Figure(PyObject <Figure size 763.636x680 with 1 Axes>)

# %%
# Out:
# В режиме Robot(...;animate==true) невозможен вызов show(::Robot,...)
#
# Stacktrace:
#  [1] error(s::String)
#    @ Base .\error.jl:35
#  [2] pre_show_actions(r::Robot)
#    @ HorizonSideRobots C:\Users\aoglo\.julia\packages\HorizonSideRobots\UumzG\src\HorizonSideRobots.jl:183
#  [3] show!(r::Robot)
#    @ HorizonSideRobots C:\Users\aoglo\.julia\packages\HorizonSideRobots\UumzG\src\HorizonSideRobots.jl:174
#  [4] top-level scope
#    @ In[155]:2
#  [5] eval
#    @ .\boot.jl:368 [inlined]
#  [6] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1428
